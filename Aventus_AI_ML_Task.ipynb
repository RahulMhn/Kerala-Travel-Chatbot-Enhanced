# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulMhn/Kerala-Travel-Chatbot-Enhanced/blob/main/Aventus_AI_ML_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = {
    'Hours_Studied': [2, 4, 5, 7, 8], # Adding a few points for a better trend
    'Score': [21, 47, 53, 70, 85]}
df = pd.DataFrame(data)

# %%
X = df[['Hours_Studied']]
y = df['Score']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
hours_to_predict = np.array([[9]])
predicted_score = model.predict(hours_to_predict)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', linewidth=2, label='Regression Line')
plt.title('Hours Studied vs Student Score')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
